# %% [markdown]
# <a href="https://colab.research.google.com/github/Gokulnaath-gif/Gokulnaath_ML/blob/main/Housing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv(r'/content/diabetes.csv')

# %%
plt.hist(df["Glucose"], bins=20)
# Out:
# (array([  5.,   0.,   0.,   0.,   1.,   3.,   7.,  25.,  63.,  93., 117.,
#          94., 102.,  61.,  54.,  41.,  31.,  25.,  28.,  18.]),
#  array([  0.  ,   9.95,  19.9 ,  29.85,  39.8 ,  49.75,  59.7 ,  69.65,
#          79.6 ,  89.55,  99.5 , 109.45, 119.4 , 129.35, 139.3 , 149.25,
#         159.2 , 169.15, 179.1 , 189.05, 199.  ]),
#  <BarContainer object of 20 artists>)

# %%
plt.title("Glucose Level Distribution")
# Out:
# Text(0.5, 1.0, 'Glucose Level Distribution')

# %%
plt.xlabel("Glucose")
plt.ylabel("Frequency")
plt.show()

# %%
plt.boxplot(df["Age"])
plt.title("Age Distribution")
plt.show()
